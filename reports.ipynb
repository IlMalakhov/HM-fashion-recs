# %%
import pandas as pd
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
# !ls data/
# Out:
# articles.csv					  images
# customers.csv					  sample_submission.csv
# h-and-m-personalized-fashion-recommendations.zip  transactions_train.csv

# %%
articles_df = pd.read_csv("data/articles.csv")
customers_df = pd.read_csv("data/customers.csv")
transactions_train_df = pd.read_csv("data/transactions_train.csv")

# %%
articles_df.shape
# Out:
# (105542, 25)

# %%
customers_df.shape
# Out:
# (1371980, 7)

# %%
transactions_train_df.shape
# Out:
# (31788324, 5)

# %%
articles_df.sample(3)
# Out:
#        article_id  product_code              prod_name  product_type_no  \
# 82512   808813001        808813          TVP Alvin set              270
# 24900   610841001        610841      Mermaid Tie Tanga               59
# 46915   687176002        687176  Margarita Mynta Thong              286
#
#       product_type_name product_group_name  graphical_appearance_no  \
# 82512       Garment Set  Garment Full body                  1010001
# 24900   Swimwear bottom           Swimwear                  1010016
# 46915  Underwear bottom          Underwear                  1010016
#
#       graphical_appearance_name  colour_group_code colour_group_name  ...  \
# 82512          All over pattern                 73         Dark Blue  ...
# 24900                     Solid                 51        Light Pink  ...
# 46915                     Solid                 42               Red  ...
#
#            department_name index_code        index_name index_group_no  \
# ...

# %%
customers_df.sample(3)
# Out:
#                                               customer_id   FN  Active  \
# 928333  ad32ae753fb32fc687bf651f2244af08ce8f47a1573239...  1.0     1.0
# 654084  7a10ce5aa2b06bdff9a37834765b0bbce62a0c59973bd3...  1.0     1.0
# 834987  9be0623b76c2ffa8565d35b9f5c6eec5d3c50c2dd8e0b3...  NaN     NaN
#
#        club_member_status fashion_news_frequency   age  \
# 928333             ACTIVE              Regularly  33.0
# 654084             ACTIVE              Regularly  29.0
# 834987             ACTIVE                   NONE  43.0
#
#                                               postal_code
# 928333  5c0832a666eccf660668664c4538423fcb8e4f75b8623e...
# 654084  04bd2e15ad1ae201b818cb053bd63ce96a5c19d9fd79bb...
# 834987  2c29ae653a9282cce4151bd87643c907644e09541abc28...

# %%
transactions_train_df.sample(3)
# Out:
#                t_dat                                        customer_id  \
# 15042886  2019-08-05  36eaf0d9c152cda131e1f9d7b5869dc383b18d284253a2...
# 29456670  2020-07-25  180e7791cf861b1b3edc968c0334b81edcefcf4d157fce...
# 11549918  2019-06-08  6c1e8549ae10ae839577b9812156e0e46d382c99017c26...
#
#           article_id     price  sales_channel_id
# 15042886   788844001  0.042356                 2
# 29456670   579541001  0.016932                 1
# 11549918   706016002  0.033881                 2

# %%
profile_articles = ProfileReport(articles_df, title="Articles Report")
profile_customers = ProfileReport(customers_df, title="Customers Report")

# %%
# profile_articles.to_file("reports/articles_report.html")
# profile_customers.to_file("reports/customers_report.html")
