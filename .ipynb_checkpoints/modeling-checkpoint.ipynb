# %% [markdown]
# ## 1. Setup & Data Loading

# %%
# !pip install autogluon
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# AutoGluon
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
DATA_PATH = Path("/home/jovyan/__DATA/APBDID_F25/data/handm")

# %%
# Load datasets
articles_df = pd.read_csv(DATA_PATH / "articles.csv")
customers_df = pd.read_csv(DATA_PATH / "customers.csv")
transactions_df = pd.read_csv(DATA_PATH / "transactions_train.csv")

print(f"Articles: {articles_df.shape}")
print(f"Customers: {customers_df.shape}")
print(f"Transactions: {transactions_df.shape}")
# Out:
# Articles: (105542, 25)
# Customers: (1371980, 7)
# Transactions: (31788324, 5)

# %%
# Quick look at transactions (our main table)
transactions_df.head()
# Out:
#         t_dat                                        customer_id  article_id  \
# 0  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   663713001
# 1  2018-09-20  000058a12d5b43e67d225668fa1f8d618c13dc232df0ca...   541518023
# 2  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   505221004
# 3  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687003
# 4  2018-09-20  00007d2de826758b65a93dd24ce629ed66842531df6699...   685687004
#
#       price  sales_channel_id
# 0  0.050831                 2
# 1  0.030492                 2
# 2  0.015237                 2
# 3  0.016932                 2
# 4  0.016932                 2

# %% [markdown]
# ## 2. Preprocessing & Train/Val/Test Split
#
# **Pipeline:**
# 1. Sample transactions (full dataset is too large for quick experiments)
# 2. Merge customer features only (avoid article feature leakage)
# 3. **Time-based split**: Train on earlier dates, validate/test on later dates
# 4. Target: `product_group_name` (what category was purchased)
#
# **Note:** We exclude article-level features (`garment_group_name`, `department_name`, etc.) since they directly encode the target and would cause leakage.

# %%
# Sample for speed - use more data for better results
SAMPLE_SIZE = 50_000
np.random.seed(42)

transactions_sample = transactions_df.sample(n=SAMPLE_SIZE, random_state=42).copy()
transactions_sample["t_dat"] = pd.to_datetime(transactions_sample["t_dat"])
print(f"Sampled transactions: {len(transactions_sample):,}")
print(f"Date range: {transactions_sample['t_dat'].min()} to {transactions_sample['t_dat'].max()}")
# Out:
# Sampled transactions: 50,000
# Date range: 2018-09-20 00:00:00 to 2020-09-22 00:00:00

# %%
# Select ONLY the target from articles (no other article features to avoid leakage)
articles_target = articles_df[["article_id", "product_group_name"]].copy()

# Select key features from customers (these are legitimate predictors)
customers_features = customers_df[[
    "customer_id",
    "club_member_status",
    "fashion_news_frequency",
    "age"
]].copy()

# Fill missing values
customers_features["club_member_status"] = customers_features["club_member_status"].fillna("UNKNOWN")
customers_features["fashion_news_frequency"] = customers_features["fashion_news_frequency"].fillna("UNKNOWN")
customers_features["age"] = customers_features["age"].fillna(customers_features["age"].median())

# %%
# Merge: transactions + customer features + target only
train_df = transactions_sample.merge(customers_features, on="customer_id", how="left")
train_df = train_df.merge(articles_target, on="article_id", how="left")

print(f"Training data shape: {train_df.shape}")
train_df.head()
# Out:
# Training data shape: (50000, 9)
#        t_dat                                        customer_id  article_id  \
# 0 2019-09-13  215895f90002eb3d1a04bd603513c8e85e6002ef08f136...   786586001
# 1 2019-02-23  7b183268e3a4623b80d5325ec4a20a0af0edff7bcb1748...   658911001
# 2 2019-07-17  2eb7412239a90c0570cd3d1bf0492856ae5b59058b1ea6...   759326005
# 3 2019-05-16  74f162e5a170fd57207aa2a7d5c58479ee9de903b2a277...   737137004
# 4 2019-08-10  aab9306ee28c4db494003955f80355e540b01480ab35cf...   785931001
#
#       price  sales_channel_id club_member_status fashion_news_frequency   age  \
# 0  0.022017                 1             ACTIVE                   NONE  41.0
# 1  0.028797                 2             ACTIVE              Regularly  30.0
# 2  0.050831                 2             ACTIVE              Regularly  22.0
# 3  0.027102                 1             ACTIVE                   NONE  21.0
# 4  0.050831                 2             ACTIVE              Regularly  49.0
#
# ...

# %%
# Simplify target: predict product_group_name instead of exact article_id
# (article_id has too many unique values for quick training)
TARGET = "product_group_name"

print(f"Target classes: {train_df[TARGET].nunique()}")
train_df[TARGET].value_counts()
# Out:
# Target classes: 15
# product_group_name
# Garment Upper body       19801
# Garment Lower body       11086
# Garment Full body         5502
# Underwear                 4036
# Swimwear                  4032
# Accessories               2577
# Shoes                     1147
# Socks & Tights            1060
# Nightwear                  585
# Unknown                    159
# Items                        7
# Bags                         4
# Cosmetic                     2
# Garment and Shoe care        1
# Furniture                    1
# Name: count, dtype: int64

# %%
# Features for training (drop IDs and date column)
drop_cols = ["customer_id", "article_id", "t_dat"]
feature_cols = [c for c in train_df.columns if c not in drop_cols and c != TARGET]

print(f"Features: {feature_cols}")

# Time-based split (important for realistic evaluation)
# Train: older transactions | Val: middle | Test: most recent
train_df_sorted = train_df.sort_values("t_dat").reset_index(drop=True)

n = len(train_df_sorted)
train_cut = int(n * 0.7)
val_cut = int(n * 0.85)

train_set = train_df_sorted.iloc[:train_cut]
val_set = train_df_sorted.iloc[train_cut:val_cut]
test_set = train_df_sorted.iloc[val_cut:]

print(f"\nTime-based split:")
print(f"  Train: {len(train_set):,} rows ({train_set['t_dat'].min().date()} to {train_set['t_dat'].max().date()})")
print(f"  Val:   {len(val_set):,} rows ({val_set['t_dat'].min().date()} to {val_set['t_dat'].max().date()})")
print(f"  Test:  {len(test_set):,} rows ({test_set['t_dat'].min().date()} to {test_set['t_dat'].max().date()})")

# Prepare datasets (drop date after split)
train_data = train_set[feature_cols + [TARGET]].copy()
val_data = val_set[feature_cols + [TARGET]].copy()
test_data = test_set[feature_cols + [TARGET]].copy()
# Out:
# Features: ['price', 'sales_channel_id', 'club_member_status', 'fashion_news_frequency', 'age']
#
# Time-based split:
#   Train: 35,000 rows (2018-09-20 to 2020-02-13)
#   Val:   7,500 rows (2020-02-13 to 2020-06-09)
#   Test:  7,500 rows (2020-06-09 to 2020-09-22)

# %% [markdown]
# ## 3. Train AutoGluon Model
#
# AutoGluon handles:
# - Automatic feature engineering
# - Model selection & ensembling
# - Hyperparameter tuning

# %%
# Convert to AutoGluon datasets
train_ag = TabularDataset(train_data)
val_ag = TabularDataset(val_data)
test_ag = TabularDataset(test_data)

# %%
# Train model with validation data
predictor = TabularPredictor(
    label=TARGET,
    eval_metric="accuracy",
    path="models/autogluon_baseline"
).fit(
    train_ag,
    tuning_data=val_ag,  # Use our time-based validation set
    time_limit=180,  # 3 minutes
    presets="optimize_for_deployment"
)
# Out:
# ...
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.12.7
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #216-Ubuntu SMP Thu Aug 29 13:26:53 UTC 2024
# CPU Count:          2
# Memory Avail:       21.51 GB / 31.35 GB (68.6%)
# Disk Space Avail:   10.42 GB / 11.71 GB (89.0%)
# ...
# Presets specified: ['optimize_for_deployment']
# Using hyperparameters preset: hyperparameters='default'
# Beginning AutoGluon training ... Time limit = 180s
# AutoGluon will save models to "/home/jovyan/HM-fashion-recs/models/autogluon_baseline"
# Train Data Rows:    35000
# Train Data Columns: 5
# Tuning Data Rows:    7500
# Tuning Data Columns: 5
# Label Column:       product_group_name
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# ...

# %% [markdown]
# ## 4. Evaluate Results

# %%
# Model leaderboard (validation performance)
print("=== Model Leaderboard (Validation Set) ===")
predictor.leaderboard(val_ag, silent=True)
# Out:
# === Model Leaderboard (Validation Set) ===
#                  model  score_test  score_val eval_metric  pred_time_test  \
# 0  WeightedEnsemble_L2    0.400133   0.400347    accuracy        1.239912
# 1      NeuralNetFastAI    0.399333   0.399546    accuracy        0.100414
# 2     RandomForestEntr    0.334400   0.334578    accuracy        1.082570
#
#    pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.407525  39.220060                 0.056928                0.001575
# 1       0.087461  32.481132                 0.100414                0.087461
# 2       0.318489   6.521204                 1.082570                0.318489
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           0.217724            2       True          3
# 1          32.481132            1       True          1
# 2           6.521204            1       True          2

# %%
# Feature importance
predictor.feature_importance(train_ag)
# Out:
# Computing feature importance via permutation shuffling for 5 features using 5000 rows with 5 shuffle sets...
# 	34.3s	= Expected runtime (6.86s per shuffle set)
# 	15.56s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                         importance    stddev   p_value  n  p99_high   p99_low
# price                      0.05376  0.004969  0.000009  5  0.063991  0.043529
# sales_channel_id           0.01548  0.002945  0.000150  5  0.021543  0.009417
# age                        0.01192  0.001316  0.000018  5  0.014630  0.009210
# fashion_news_frequency     0.00676  0.000654  0.000010  5  0.008107  0.005413
# club_member_status         0.00172  0.000593  0.001460  5  0.002942  0.000498

# %%
# Final evaluation on TEST set (unseen future data)
print("=== Test Set Evaluation ===")
test_score = predictor.evaluate(test_ag)
print(f"Test Accuracy: {test_score}")

# Predictions on test set
test_preds = predictor.predict(test_ag.drop(columns=[TARGET]))
print(f"\nSample predictions vs actuals:")
comparison = pd.DataFrame({
    "Predicted": test_preds[:10].values,
    "Actual": test_ag[TARGET][:10].values
})
print(comparison)
# Out:
# === Test Set Evaluation ===
# Test Accuracy: {'accuracy': 0.37493333333333334, 'balanced_accuracy': 0.11407173805964956, 'mcc': 0.09397899079871992}
#
# Sample predictions vs actuals:
#             Predicted              Actual
# 0  Garment Upper body  Garment Upper body
# 1  Garment Upper body  Garment Lower body
# 2  Garment Upper body           Underwear
# 3  Garment Upper body            Swimwear
# 4  Garment Upper body  Garment Upper body
# 5  Garment Upper body            Swimwear
# 6  Garment Upper body  Garment Upper body
# 7  Garment Upper body      Socks & Tights
# 8  Garment Upper body            Swimwear
# 9  Garment Upper body  Garment Upper body

# %%
# Detailed classification report
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

print("=== Classification Report (Test Set) ===")
print(classification_report(test_ag[TARGET], test_preds, zero_division=0))

# Confusion matrix for top classes
top_classes = train_data[TARGET].value_counts().head(5).index.tolist()
mask = test_ag[TARGET].isin(top_classes)

cm = confusion_matrix(
    test_ag[TARGET][mask], 
    test_preds[mask], 
    labels=top_classes
)

# Style for transparent background + white text (Deckset-ready)
plt.rcParams.update({
    "figure.facecolor": "none",
    "axes.facecolor": "none",
    "savefig.facecolor": "none",
    "text.color": "white",
    "axes.labelcolor": "white",
    "axes.titlecolor": "white",
    "xtick.color": "white",
    "ytick.color": "white",
    "axes.edgecolor": "white",
})

fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", 
            xticklabels=top_classes, yticklabels=top_classes,
            annot_kws={"color": "white", "fontsize": 12},
            cbar_kws={"shrink": 0.8}, ax=ax)
ax.set_xlabel("Predicted", fontsize=12)
ax.set_ylabel("Actual", fontsize=12)
ax.set_title("Confusion Matrix (Top 5 Classes)", fontsize=14, fontweight="bold", pad=12)
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)

fig.tight_layout()
fig.savefig("confusion_matrix.png", dpi=300, transparent=True, bbox_inches="tight")
plt.show()
print("\nSaved: confusion_matrix.png")
# Out:
# === Classification Report (Test Set) ===
#                     precision    recall  f1-score   support
#
#        Accessories       0.44      0.08      0.13       339
#  Garment Full body       0.24      0.02      0.04      1040
# Garment Lower body       0.38      0.33      0.35      1671
# Garment Upper body       0.38      0.83      0.52      2680
#              Items       0.00      0.00      0.00         3
#          Nightwear       0.00      0.00      0.00        64
#              Shoes       0.00      0.00      0.00       151
#     Socks & Tights       0.00      0.00      0.00       140
#           Swimwear       0.00      0.00      0.00       722
#          Underwear       0.00      0.00      0.00       622
#            Unknown       0.00      0.00      0.00        68
#
#           accuracy                           0.37      7500
#          macro avg       0.13      0.11      0.09      7500
#       weighted avg       0.27      0.37      0.27      7500
# ...

# %% [markdown]
# ## 5. Next Steps
#
# To improve the model:
# 1. **More data**: Increase `SAMPLE_SIZE`
# 2. **Better features**: Add lag features from transaction history (as shown in class)
# 3. **Longer training**: Increase `time_limit` or use `best_quality` preset
# 4. **Different target**: Try predicting `department_name` or `index_group_name`
# 5. **Evaluation**: Use proper train/validation/test split by time
